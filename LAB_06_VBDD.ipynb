# %% [markdown]
# <a href="https://colab.research.google.com/github/victoria0631/ML/blob/main/LAB_06_VBDD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MPA-MLF, Lab 6 - Feedforward Neural Networks with regularization techniques and hyperparameter tunning

# %% [markdown]
# ## Exercise 1 - Classification of an images

# %% [markdown]
# The goal of this task will be to create Multi-layer perceptron model, that is able to recognize the  CIFAR10 dataset (https://www.cs.toronto.edu/~kriz/cifar.html). The CIFAR10 dataset consist of 60000 images with resolution of 32x32 pixels. There are 10 classes in total - *airplane*, *automobile*, *bird*, *cat*, *deer*, *dog*, *frog*, *horse*, *ship*, *truck*

# %% [markdown]
# These is an example of the dataset:

# %% [markdown]
# ![cifar10.png](data:image/png;base64,...)

# %% [markdown]
# ### 0. Import libraries

# %%
from keras.models import Sequential
from keras.layers import Dense, Flatten, BatchNormalization, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping
from keras.optimizers import SGD
from keras.datasets import cifar10
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
from tensorflow.keras import optimizers
import cv2
from tensorflow.keras import layers, models, regularizers
font = {'weight' : 'bold',
        'size'   : 12}

matplotlib.rc('font', **font)

# %% [markdown]
# ### 1. Load the Dataset
# The dataset is already a part of the Keras library, so we can quickly load it using the following command

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %% [markdown]
# The following numbered labels represent the labels in the dataset:

# %%
labels = {0:'airplane',1:'automobile',2:'bird',3:'cat',4:'deer',5:'dog',6:'frog',7:'horse',8:'ship',9:'truck'}

# %% [markdown]
# ### 2. Data Examination

# %% [markdown]
# Fistly, lets have a look and the couple of images we have,

# %%
def display_random_images(x_data: np.array, y_data: np.array, count: int = 10) -> None:
  index = np.array(len(x_data))
  selected_ind = np.random.choice(index, count)

  selected_img = x_data[selected_ind]
  selected_labels_encoded = y_data[selected_ind]
  selected_labels = [labels[x[0]] for x in selected_labels_encoded]

  concat_img = np.concatenate(selected_img, axis=1)

  plt.figure(figsize=(20,10))
  plt.imshow(concat_img)

  for id_label, label in enumerate(selected_labels):
    plt.text((32/2) + 32*id_label - len(label), 32*(5/4), label)
  plt.axis('off')
  plt.show()

# %%
display_random_images(X_train, y_train)

# %%
#check the shape of image dataset

X_train.shape
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# In our dataset, we have 60000 images with 32x32 resolution. Each image has three channels (R, G, B). We have 50000 images for training and 10000 images for testing. Each channel for each image has values from 0 - 255, where each number represents the pixel intensity.
# With the combination of intensities of R, G and B, you can display up to 16,777,216 different colours (256^3)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Here you can display each channel separately:

# %%
def display_channels_separately(image: np.array) -> None:

  plt.figure()
  fig, axs = plt.subplots(nrows=1, ncols=4, figsize=(10, 5))


  axs[0].imshow(image[:,:,0],cmap='Reds')
  axs[1].imshow(image[:,:,1],cmap='Blues')
  axs[2].imshow(image[:,:,2],cmap='Greens')

  axs[3].imshow(image)

  plt.show()

# %%
display_channels_separately(X_train[0])

# %% [markdown]
# ### 3. Preprocessing of the images

# %% [markdown]
# For machine learning purposes, we have to preprocess our images. Firstly we need to scale our images, to scale intensity values from 0-1 (min-max scaling)

# %%
X_train_scaled = X_train.astype('float32') / 255.0

# %% [markdown]
# We need to one-hot-encode the labels in our ground truth variable as our second preprocessing.

# %%
y_train_encoded = to_categorical(y_train, num_classes=10)

# %% [markdown]
# ### 4. Define the model architecture

# %%
from tensorflow.keras import layers, models, regularizers, callbacks

model = models.Sequential([
    layers.Flatten(input_shape=(32, 32, 3)),

    # Couche 1
    layers.Dense(1024, kernel_regularizer=regularizers.l2(0.0005)),
    layers.BatchNormalization(),
    layers.Activation('elu'),
    layers.Dropout(0.3),

    # Couche 2
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0005)),
    layers.BatchNormalization(),
    layers.Activation('elu'),
    layers.Dropout(0.3),

    # Couche 3
    layers.Dense(256, kernel_regularizer=regularizers.l2(0.0005)),
    layers.BatchNormalization(),
    layers.Activation('elu'),
    layers.Dropout(0.2),

    layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# We will define *the Sequential* model as in our last exercise. This time we will use a different approach to determine the input layers. Instead of specifying the *input_dim* parameter in our first hidden layer, we will create a **Flatten** layer that takes our 32x32x3 image and reshapes it into 1x3072.
#
# We will specify ten neurons in our output layer because we have 10 possible outputs and a **softmax** activation function that returns us a probability distribution over the classes. The class with the highest probability is typically chosen as the predicted class for a given input.

# %% [markdown]
# Check the description of our model:

# %%
model.summary()
# Out:
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_11 (Flatten)            │ (None, 3072)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_44 (Dense)                │ (None, 1024)           │     3,146,752 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_30          │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_24 (Activation)      │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_30 (Dropout)            │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_45 (Dense)                │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_31          │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_25 (Activation)      │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_31 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_46 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_32          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_26 (Activation)      │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_32 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_47 (Dense)                │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,812,618 (14.54 MB)
#  Trainable params: 3,809,034 (14.53 MB)
#  Non-trainable params: 3,584 (14.00 KB)

# %% [markdown]
# The next step is to compile our model, we will use *categorical_crossentropy* as a loss function, *stochastic gradient descend* as an optimisation and we will be checking *the accuracy* metric.

# %%
lr_reducer = callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    verbose=1,
    min_lr=1e-6
)

early_stop = callbacks.EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True # Très important : garde le meilleur état du modèle
)

# %% [markdown]
# ### 5. Train the model

# %% [markdown]
# Our model will be trained in the same way as in our last pc_labs,

# %%
# 4. Entraînement avec tes variables exactes
history = model.fit(
    X_train_scaled, y_train_encoded,
    epochs=100,
    batch_size=64,
    validation_split=0.2,
    callbacks=[lr_reducer, early_stop]
)
# Out:
# Epoch 1/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.3402 - loss: 2.7434 - val_accuracy: 0.3536 - val_loss: 2.3509 - learning_rate: 0.0010
# Epoch 2/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.3857 - loss: 2.1242 - val_accuracy: 0.3305 - val_loss: 2.1431 - learning_rate: 0.0010
# Epoch 3/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.3986 - loss: 1.9857 - val_accuracy: 0.2908 - val_loss: 2.3191 - learning_rate: 0.0010
# Epoch 4/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4034 - loss: 1.9316 - val_accuracy: 0.3252 - val_loss: 2.1828 - learning_rate: 0.0010
# Epoch 5/100
# 613/625 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4068 - loss: 1.9126
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4066 - loss: 1.9067 - val_accuracy: 0.2197 - val_loss: 2.6605 - learning_rate: 0.0010
# Epoch 6/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.4347 - loss: 1.7913 - val_accuracy: 0.3169 - val_loss: 2.1733 - learning_rate: 5.0000e-04
# Epoch 7/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4397 - loss: 1.7551 - val_accuracy: 0.3856 - val_loss: 1.9128 - learning_rate: 5.0000e-04
# Epoch 8/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4451 - loss: 1.7376 - val_accuracy: 0.4200 - val_loss: 1.8532 - learning_rate: 5.0000e-04
# Epoch 9/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.4509 - loss: 1.7221 - val_accuracy: 0.3886 - val_loss: 1.9280 - learning_rate: 5.0000e-04
# Epoch 10/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.4532 - loss: 1.7073 - val_accuracy: 0.3417 - val_loss: 2.0716 - learning_rate: 5.0000e-04
# Epoch 11/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4612 - loss: 1.6872
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4587 - loss: 1.6929 - val_accuracy: 0.3855 - val_loss: 1.9500 - learning_rate: 5.0000e-04
# Epoch 12/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4849 - loss: 1.6109 - val_accuracy: 0.3976 - val_loss: 1.8127 - learning_rate: 2.5000e-04
# Epoch 13/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4951 - loss: 1.5718 - val_accuracy: 0.4765 - val_loss: 1.6212 - learning_rate: 2.5000e-04
# Epoch 14/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5011 - loss: 1.5551 - val_accuracy: 0.4398 - val_loss: 1.7339 - learning_rate: 2.5000e-04
# Epoch 15/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4995 - loss: 1.5469 - val_accuracy: 0.4450 - val_loss: 1.7049 - learning_rate: 2.5000e-04
# Epoch 16/100
# 619/625 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5145 - loss: 1.5052
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5083 - loss: 1.5203 - val_accuracy: 0.4420 - val_loss: 1.7141 - learning_rate: 2.5000e-04
# Epoch 17/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5279 - loss: 1.4580 - val_accuracy: 0.4587 - val_loss: 1.7005 - learning_rate: 1.2500e-04
# Epoch 18/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5309 - loss: 1.4391 - val_accuracy: 0.4640 - val_loss: 1.6766 - learning_rate: 1.2500e-04
# Epoch 19/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5387 - loss: 1.4212 - val_accuracy: 0.4772 - val_loss: 1.5744 - learning_rate: 1.2500e-04
# Epoch 20/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5427 - loss: 1.4089 - val_accuracy: 0.5098 - val_loss: 1.5148 - learning_rate: 1.2500e-04
# Epoch 21/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5459 - loss: 1.3930 - val_accuracy: 0.4667 - val_loss: 1.6683 - learning_rate: 1.2500e-04
# Epoch 22/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5466 - loss: 1.3881 - val_accuracy: 0.4892 - val_loss: 1.5956 - learning_rate: 1.2500e-04
# Epoch 23/100
# 619/625 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5560 - loss: 1.3648
# Epoch 23: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5499 - loss: 1.3784 - val_accuracy: 0.4765 - val_loss: 1.6191 - learning_rate: 1.2500e-04
# Epoch 24/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5670 - loss: 1.3321 - val_accuracy: 0.5263 - val_loss: 1.4482 - learning_rate: 6.2500e-05
# Epoch 25/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5705 - loss: 1.3161 - val_accuracy: 0.5191 - val_loss: 1.4755 - learning_rate: 6.2500e-05
# Epoch 26/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5771 - loss: 1.3008 - val_accuracy: 0.5402 - val_loss: 1.4158 - learning_rate: 6.2500e-05
# Epoch 27/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5796 - loss: 1.2943 - val_accuracy: 0.5057 - val_loss: 1.5108 - learning_rate: 6.2500e-05
# Epoch 28/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.5836 - loss: 1.2806 - val_accuracy: 0.5118 - val_loss: 1.4880 - learning_rate: 6.2500e-05
# Epoch 29/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5902 - loss: 1.2576
# Epoch 29: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5835 - loss: 1.2738 - val_accuracy: 0.5132 - val_loss: 1.4979 - learning_rate: 6.2500e-05
# Epoch 30/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5957 - loss: 1.2428 - val_accuracy: 0.5559 - val_loss: 1.3809 - learning_rate: 3.1250e-05
# Epoch 31/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5983 - loss: 1.2298 - val_accuracy: 0.5462 - val_loss: 1.4040 - learning_rate: 3.1250e-05
# Epoch 32/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6021 - loss: 1.2229 - val_accuracy: 0.5480 - val_loss: 1.3929 - learning_rate: 3.1250e-05
# Epoch 33/100
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6075 - loss: 1.2155
# Epoch 33: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6059 - loss: 1.2171 - val_accuracy: 0.5420 - val_loss: 1.4190 - learning_rate: 3.1250e-05
# Epoch 34/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6095 - loss: 1.2001 - val_accuracy: 0.5530 - val_loss: 1.3794 - learning_rate: 1.5625e-05
# Epoch 35/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6152 - loss: 1.1868 - val_accuracy: 0.5554 - val_loss: 1.3673 - learning_rate: 1.5625e-05
# Epoch 36/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6170 - loss: 1.1774 - val_accuracy: 0.5464 - val_loss: 1.4153 - learning_rate: 1.5625e-05
# Epoch 37/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6174 - loss: 1.1749 - val_accuracy: 0.5542 - val_loss: 1.3879 - learning_rate: 1.5625e-05
# Epoch 38/100
# 619/625 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6221 - loss: 1.1656
# Epoch 38: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6218 - loss: 1.1677 - val_accuracy: 0.5437 - val_loss: 1.4194 - learning_rate: 1.5625e-05
# Epoch 39/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6222 - loss: 1.1640 - val_accuracy: 0.5662 - val_loss: 1.3561 - learning_rate: 7.8125e-06
# Epoch 40/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6260 - loss: 1.1519 - val_accuracy: 0.5649 - val_loss: 1.3653 - learning_rate: 7.8125e-06
# Epoch 41/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6237 - loss: 1.1581 - val_accuracy: 0.5621 - val_loss: 1.3567 - learning_rate: 7.8125e-06
# Epoch 42/100
# 618/625 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6300 - loss: 1.1422
# Epoch 42: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6293 - loss: 1.1491 - val_accuracy: 0.5607 - val_loss: 1.3618 - learning_rate: 7.8125e-06
# Epoch 43/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6289 - loss: 1.1442 - val_accuracy: 0.5662 - val_loss: 1.3508 - learning_rate: 3.9063e-06
# Epoch 44/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6313 - loss: 1.1404 - val_accuracy: 0.5679 - val_loss: 1.3511 - learning_rate: 3.9063e-06
# Epoch 45/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6302 - loss: 1.1390 - val_accuracy: 0.5656 - val_loss: 1.3461 - learning_rate: 3.9063e-06
# Epoch 46/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6318 - loss: 1.1348 - val_accuracy: 0.5663 - val_loss: 1.3501 - learning_rate: 3.9063e-06
# Epoch 47/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6334 - loss: 1.1381 - val_accuracy: 0.5616 - val_loss: 1.3604 - learning_rate: 3.9063e-06
# Epoch 48/100
# 623/625 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6360 - loss: 1.1248
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6345 - loss: 1.1299 - val_accuracy: 0.5623 - val_loss: 1.3576 - learning_rate: 3.9063e-06
# Epoch 49/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6340 - loss: 1.1299 - val_accuracy: 0.5659 - val_loss: 1.3534 - learning_rate: 1.9531e-06
# Epoch 50/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6342 - loss: 1.1325 - val_accuracy: 0.5671 - val_loss: 1.3481 - learning_rate: 1.9531e-06
# Epoch 51/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6356 - loss: 1.1203
# Epoch 51: ReduceLROnPlateau reducing learning rate to 1e-06.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6369 - loss: 1.1255 - val_accuracy: 0.5639 - val_loss: 1.3480 - learning_rate: 1.9531e-06
# Epoch 52/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.6348 - loss: 1.1237 - val_accuracy: 0.5655 - val_loss: 1.3463 - learning_rate: 1.0000e-06
# Epoch 53/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6351 - loss: 1.1210 - val_accuracy: 0.5644 - val_loss: 1.3468 - learning_rate: 1.0000e-06
# Epoch 54/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6363 - loss: 1.1259 - val_accuracy: 0.5644 - val_loss: 1.3458 - learning_rate: 1.0000e-06
# Epoch 55/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6370 - loss: 1.1188 - val_accuracy: 0.5664 - val_loss: 1.3472 - learning_rate: 1.0000e-06
# Epoch 56/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.6405 - loss: 1.1184 - val_accuracy: 0.5663 - val_loss: 1.3455 - learning_rate: 1.0000e-06
# Epoch 57/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6348 - loss: 1.1251 - val_accuracy: 0.5671 - val_loss: 1.3479 - learning_rate: 1.0000e-06
# Epoch 58/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6359 - loss: 1.1209 - val_accuracy: 0.5658 - val_loss: 1.3477 - learning_rate: 1.0000e-06
# Epoch 59/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6351 - loss: 1.1278 - val_accuracy: 0.5688 - val_loss: 1.3495 - learning_rate: 1.0000e-06
# Epoch 60/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6393 - loss: 1.1188 - val_accuracy: 0.5665 - val_loss: 1.3467 - learning_rate: 1.0000e-06
# Epoch 61/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6371 - loss: 1.1172 - val_accuracy: 0.5670 - val_loss: 1.3448 - learning_rate: 1.0000e-06
# Epoch 62/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6402 - loss: 1.1178 - val_accuracy: 0.5651 - val_loss: 1.3477 - learning_rate: 1.0000e-06
# Epoch 63/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6357 - loss: 1.1184 - val_accuracy: 0.5657 - val_loss: 1.3476 - learning_rate: 1.0000e-06
# Epoch 64/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.6381 - loss: 1.1173 - val_accuracy: 0.5668 - val_loss: 1.3476 - learning_rate: 1.0000e-06
# Epoch 65/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6408 - loss: 1.1126 - val_accuracy: 0.5662 - val_loss: 1.3457 - learning_rate: 1.0000e-06
# Epoch 66/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6379 - loss: 1.1183 - val_accuracy: 0.5682 - val_loss: 1.3452 - learning_rate: 1.0000e-06
# Epoch 67/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6407 - loss: 1.1141 - val_accuracy: 0.5686 - val_loss: 1.3449 - learning_rate: 1.0000e-06
# Epoch 68/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6385 - loss: 1.1169 - val_accuracy: 0.5633 - val_loss: 1.3460 - learning_rate: 1.0000e-06
# Epoch 69/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6385 - loss: 1.1113 - val_accuracy: 0.5670 - val_loss: 1.3461 - learning_rate: 1.0000e-06
# Epoch 70/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6388 - loss: 1.1181 - val_accuracy: 0.5682 - val_loss: 1.3460 - learning_rate: 1.0000e-06
# Epoch 71/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6398 - loss: 1.1172 - val_accuracy: 0.5679 - val_loss: 1.3451 - learning_rate: 1.0000e-06

# %% [markdown]
# ### 6. Model evaluation

# %%
X_test = X_test.astype('float32') / 255.0
y_test_encoded = to_categorical(y_test, num_classes=10)

# %%
score = model.evaluate(X_test, y_test_encoded, verbose=0)
print('Test loss:', score[0])
print(f'Test accuracy: {score[1]*100} %')
# Out:
# Test loss: 1.343314528465271
# Test accuracy: 55.959999561309814 %

# %%
plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
plt.figure()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

# %% [markdown]
# As you can see from the evaluation above, we was able to achive approx. 30% of an accuracy. In other word approx. 70% of an images we classified wrongly. That is really bad!

# %% [markdown]
# Lets check the best predictions from our model:

# %%
def show_the_best_predictions(model, x_test: np.array, y_test: np.array, n_of_pred: int = 10) -> None:
  mapping = {0:'airplane',1:'automobile',2:'bird',3:'cat',4:'deer',5:'dog',6:'frog',7:'horse',8:'ship',9:'truck'}

  predictions = model.predict(x_test)
  y_test = y_test.reshape(1,-1)
  predictions_ind = np.argmax(predictions, axis=1)
  predictions_ind = predictions_ind.reshape(1, -1)

  corect_predictions = np.where(predictions_ind == y_test)

  rows_correct = corect_predictions[1]
  predictedtions_correct = predictions[rows_correct]
  target_correct = y_test[0][rows_correct]

  max_samples = predictions[rows_correct, target_correct]
  selected_images = x_test[rows_correct]
  sorted_ind = np.argsort(max_samples)[::-1]


  images = []
  prob = []
  labels = []


  for ind in range(n_of_pred):

    index = sorted_ind[ind]

    labels.append(target_correct[index])
    prob.append(max_samples[index])
    images.append(selected_images[index])

  plt.figure(figsize=(20,10))

  images = np.concatenate(np.asarray(images),axis=1)
  plt.imshow(images)
  for ins in range(n_of_pred):
    texts = '{}: \n{:.3f} %'.format(mapping[labels[ins]], prob[ins]*100)
    plt.text((32/2) + 32*ins - len(mapping[labels[ins]]), 32*(5/4), texts)

  plt.axis('off')
  plt.show()

# %%
show_the_best_predictions(model, X_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
#juste because I wanted to see...
def show_the_worst_predictions(model, x_test: np.array, y_test: np.array, n_of_pred: int = 10) -> None:
    mapping = {0:'airplane',1:'automobile',2:'bird',3:'cat',4:'deer',5:'dog',6:'frog',7:'horse',8:'ship',9:'truck'}

    predictions = model.predict(x_test)
    y_test = y_test.reshape(1, -1)

    predictions_ind = np.argmax(predictions, axis=1)
    predictions_ind = predictions_ind.reshape(1, -1)


    wrong_predictions = np.where(predictions_ind != y_test)

    rows_wrong = wrong_predictions[1]
    predictions_wrong = predictions[rows_wrong]

    predicted_labels = predictions_ind[0][rows_wrong]
    true_labels = y_test[0][rows_wrong]

    max_samples = predictions[rows_wrong, predicted_labels]

    selected_images = x_test[rows_wrong]

    sorted_ind = np.argsort(max_samples)[::-1]

    images = []
    prob = []
    labels_pred = []
    labels_true = []

    for ind in range(n_of_pred):
        index = sorted_ind[ind]

        labels_pred.append(predicted_labels[index])
        labels_true.append(true_labels[index])
        prob.append(max_samples[index])
        images.append(selected_images[index])

    plt.figure(figsize=(20,10))

    images = np.concatenate(np.asarray(images), axis=1)
    plt.imshow(images)

    for ins in range(n_of_pred):
        texts = 'Pred: {} \nTrue: {}\n{:.3f} %'.format(
            mapping[labels_pred[ins]],
            mapping[labels_true[ins]],
            prob[ins] * 100
        )
        plt.text((32/2) + 32*ins - len(mapping[labels_pred[ins]]), 32*(5/4), texts)

    plt.axis('off')
    plt.show()

# %%
show_the_worst_predictions(model, X_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %% [markdown]
# ### Task Description:

# %% [markdown]
# You task of this exercise would be to improve the model's performance to achieve better results in image classification task. There is no need to change the preprocessing of the dataset. There are possible way how to improve the models performance:

# %% [markdown]
# 1. Hyperparameter tunning - change the hyperparameters so that the model will perform better. You can experiment with the following:
#  - *changing the number of neurons in the hidden layer*
#  - *changing the number of hidden layers*
#  - *changing the activation functions*
#  - *changing the learning rate*
#  - *changing the optimizer* - So far, we have used only Gradient descend as our optimizer, but Keras offers other algorithms that can perform better - check the documentation!
#  - *changing the number of learning epochs*\
#  - *changing the batch size*
#
# 2. Regularization techniques - There are several regularization techniques that can improve the model's performance:
#  - *Dropout* -  In the Keras lib. you can add *dropout layer* into your Sequential model using the following command  *model.add(Dropout(p))* where *p* is an hyperparameter that controls dropout probabily, typical values are 0.1 - 0.5.
#  - *L1, L2 regularization* - In keras the regularization is applied for selected layers, there is an example how to add l2 regularization to an layer (for more details check the documnetation):  *model.add(Dense(64, activation='relu', input_dim=100, kernel_regularizer=l2(0.01)))*
#  - *Early stopping* -  In Keras, you can use the EarlyStopping callback to implement early stopping in your model. *early_stopping = EarlyStopping(monitor='val_loss', patience=3)*,  *model.fit(X_train, y_train, epochs=100, validation_data=(X_val, y_val), callbacks=[early_stopping])*

# %% [markdown]
# Try to make the highest testing accuracy possible. You can directly edit the code that is presented above, or you can copy everything into new cells. Please submit only the code with the best performance and briefly describe what approaches you have tried and what were the results

# %% [markdown]
# ### WRITE YOUR DESCRIPTION IN THIS CELL ### :
# 1- The Initial Problem
# The Observation: A simple neural network learns training images "by heart" (overfitting), so it cannot recognize new images.
#
# 2- The Improvement Process
# Regularization (Dropout & L2):
#
# Why: Dropout randomly turns off neurons so the network doesn't rely on a single piece of information. L2 prevents calculations from becoming too extreme.
#
# Change of Optimizer (Adam):
#
# Why: The basic SGD is too slow and not efficient enough. Adam is an autopilot that manages its own speed to reach the best score faster.
#
# Batch Normalization:
#
# The graphs were too erratic. We added this to stabilize the calculations between each layer and make the model more robust. It's not perfect yet, but it's better.
#
# Adjustments to achieve 50% accuracy:
#
# ELU Activation: Better than ReLU to prevent certain neurons from stopping working ("dead neurons").
#
# Dynamic Learning Rate (ReduceLR): The model is instructed to slow down as it approaches the target to improve accuracy.
#
# Early Stopping: Everything is stopped as soon as the model starts overfitting to maintain the best version (and therefore a high number of epochs can be used).

# %% [markdown]
# ### Voluntary task:
# Implement one of the hyperparameter tunning algorithms discussed in the lecture, such as *Grid Search*, *Random Search* or more sophisticated ones. Some of these algorithms are already included in the Keras. Check the documentation
